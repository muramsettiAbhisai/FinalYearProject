# %% [markdown]
# <a href="https://colab.research.google.com/github/muramsettiAbhisai/FinalYearProject/blob/main/ACDC_ASPP_MIGHT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget  "https://zenodo.org/records/15038913/files/ACDC.zip?download=1"
# !git clone https://github.com/Dootmaan/MT-UNet.git
# %cd /content/MT-UNet
# !pip install medpy
# Out:
# --2025-03-20 11:03:02--  https://zenodo.org/records/15038913/files/ACDC.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110678618 (106M) [application/octet-stream]
# Saving to: ‘ACDC.zip?download=1’
#
# ACDC.zip?download=1 100%[===================>] 105.55M  91.3MB/s    in 1.2s
#
# 2025-03-20 11:03:03 (91.3 MB/s) - ‘ACDC.zip?download=1’ saved [110678618/110678618]
#
# Cloning into 'MT-UNet'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 91 (delta 13), reused 12 (delta 9), pack-reused 72 (from 1)
# Receiving objects: 100% (91/91), 37.96 KiB | 12.65 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/MT-UNet
# ...

# %%
# !unzip ../ACDC.zip -d /content/dataset/
# Out:
# Archive:  ../ACDC.zip
#    creating: /content/dataset/ACDC/
#    creating: /content/dataset/ACDC/valid/
#   inflating: /content/dataset/ACDC/valid/case_033_sliceED_7.npz
#   inflating: /content/dataset/ACDC/valid/case_029_sliceES_10.npz
#   inflating: /content/dataset/ACDC/valid/case_061_sliceES_2.npz
#   inflating: /content/dataset/ACDC/valid/case_076_sliceED_2.npz
#   inflating: /content/dataset/ACDC/valid/case_061_sliceES_0.npz
#   inflating: /content/dataset/ACDC/valid/case_021_sliceED_7.npz
#   inflating: /content/dataset/ACDC/valid/case_033_sliceES_8.npz
#   inflating: /content/dataset/ACDC/valid/case_041_sliceES_4.npz
#   inflating: /content/dataset/ACDC/valid/case_021_sliceES_3.npz
#   inflating: /content/dataset/ACDC/valid/case_061_sliceES_1.npz
#   inflating: /content/dataset/ACDC/valid/case_029_sliceED_6.npz
#   inflating: /content/dataset/ACDC/valid/case_071_sliceED_0.npz
#   inflating: /content/dataset/ACDC/valid/case_076_sliceED_3.npz
# ...

# %%
# !unzip /content/MT-UNet/dataset/lists_Synapse.zip -d /content/MT-UNet/dataset/lists_Synapse_folder
# Out:
# Archive:  /content/MT-UNet/dataset/lists_Synapse.zip
#    creating: /content/MT-UNet/dataset/lists_Synapse_folder/lists_Synapse/
#   inflating: /content/MT-UNet/dataset/lists_Synapse_folder/lists_Synapse/train.txt
#   inflating: /content/MT-UNet/dataset/lists_Synapse_folder/lists_Synapse/test.txt
#   inflating: /content/MT-UNet/dataset/lists_Synapse_folder/lists_Synapse/all.lst

# %%
# Out:
# /content/MT-UNet

# %%
# !python3 -u train_mtunet_ACDC.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-03-20 12:25:06,916   INFO   iteration 6660 : loss : 0.026114 lr_: 0.000069
# 2025-03-20 12:25:07,535   INFO   iteration 6661 : loss : 0.028767 lr_: 0.000069
# 2025-03-20 12:25:08,160   INFO   iteration 6662 : loss : 0.046077 lr_: 0.000069
# 2025-03-20 12:25:08,792   INFO   iteration 6663 : loss : 0.020652 lr_: 0.000069
# 2025-03-20 12:25:09,431   INFO   iteration 6664 : loss : 0.025575 lr_: 0.000069
# 2025-03-20 12:25:10,073   INFO   iteration 6665 : loss : 0.023531 lr_: 0.000069
# 2025-03-20 12:25:10,701   INFO   iteration 6666 : loss : 0.020227 lr_: 0.000069
# 2025-03-20 12:25:11,325   INFO   iteration 6667 : loss : 0.021981 lr_: 0.000069
# 2025-03-20 12:25:11,955   INFO   iteration 6668 : loss : 0.048180 lr_: 0.000069
# 2025-03-20 12:25:12,582   INFO   iteration 6669 : loss : 0.022331 lr_: 0.000069
# 2025-03-20 12:25:13,209   INFO   iteration 6670 : loss : 0.028839 lr_: 0.000069
# ...

# %%
# !pip install medpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 MB 13.1 MB/s eta 0:00:00
# ...
#   Created wheel for medpy: filename=MedPy-0.5.2-py3-none-any.whl size=224709 sha256=3ed575fd440c0e977043c943c8f2c4fcbd1dfa0743575b5919a8c956a36b6c34
#   Stored in directory: /root/.cache/pip/wheels/d4/33/ed/aaac5a347fb8d41679ca515b8f5c49dfdf49be15bdbb9a905d
# Successfully built medpy
# ...

# %%
#batch matrix multiplication
#unsqueeze
#squeeze
